# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivekdesai25/Evoastra-Internship/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
url="https://www.cars24.com/buy-used-mg-cars-mumbai/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}
req=requests.get(url,headers=headers)
soup=BeautifulSoup(req.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://assets.cars24.com" rel="preconnect"/>
#   <link href="https://media.cars24.com" rel="preconnect"/>
#   <link href="https://connect.facebook.net" rel="preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://analytics.twitter.com" rel="preconnect"/>
#   <link href="https://www.facebook.com" rel="preconnect"/>
#   <link href="https://www.google.com" rel="preconnect"/>
#   <link href="https://www.google.co.in" rel="preconnect"/>
#   <link href="https://googleads.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://t.co" rel="preconnect"/>
#   <link href="https://static.ads-twitter.com" rel="preconnect"/>
#   <link href="https://tracking.cars24.com" rel="preconnect"/>
#   <link href="https://gumi.criteo.com" rel="preconnect"/>
#   <link href="https://dynamic.criteo.com" rel="preconnect"/>
#   <link href="https://tr.snapchat.com" rel="preconnect"/>
#   <link href="https://pixel.tapad.com" rel="preconnect"/>
#   <link href="https://sslwidget.criteo.com" rel="preconnect"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=5, user-scalable=yes" name="viewport"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/2a77d98cdd5f3c37.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/3854d84bc32e80ae.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/71a2bb674e8dcf57.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/5bcd6b8d285f86c4.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/497a6f119df025ba.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/a041b41b8b19eba9.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/a8c0e939ae5a3171.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/7dd7e5b498e86830.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/bb79fda467cbd0b4.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/04d85bc0ea4bf438.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/f349509ec6c23a5f.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/11296da54b128758.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/0db3c9b1be12ae8c.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/f47086f23be5f514.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/08eed280d85004d9.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/4d70946f48a75205.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/6133e611b03ee5a9.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/54f17f48d07412aa.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/981970c32166e68c.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/0d44b4cf0660fb9b.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/1e670d94e628ab85.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/311e7c9e988043f1.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/ec2252501a9455e3.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/3c4ceee8e474adc9.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/d205b6e1b6218efb.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/e0bfc094848619b5.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/89101f85f6d0f869.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/851deb3e11c4e1c8.css" rel="stylesheet"/>
#   <link as="script" fetchpriority="low" href="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/webpack-0b0584129aacd43f.js" rel="preload"/>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/1dd3208c-015fc21e435b8db5.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/1528-4aee942a4a125351.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/main-app-b785dae62bcd5af3.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/32278-88cb87eb93f83e53.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/22147-10716e29dd63ea52.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/app/layout-f70af6688967b921.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/77695-debf32a62c56802c.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/21144-4a827b65b150c9af.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/40588-ba98c8be9ca14fe4.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/20417-8c2bd254f8825667.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/54527-8d952d7166ddcd14.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/82664-d9b093e491026d29.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/61155-79311f81a0cc7b6b.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/18150-ad0d182d1811a79a.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/3155-1425738c63cfed04.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/1445-503343cd01cd99e2.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/30700-3c2da34faf3a3a56.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/63014-d9af4485d0b4d7aa.js">
#   </script>
#   <script async="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/app/desktop/layout-bfefddae722379e1.js">
#   </script>
#   <link as="script" href="https://www.googletagmanager.com/gtm.js?id=GTM-P3C9RJ" rel="preload"/>
#   <title>
#    Used MG Cars in Mumbai, Second Hand MG Cars starting from ₹9.90 lakh – CARS24
#   </title>
#   <meta content="Looking to buy a second hand MG car in Mumbai? CARS24 offers a hassle-free experience with a wide range of popular models like  &lt;strong&gt;MG HECTOR&lt;/strong&gt;, &lt;strong&gt;MG HECTOR PLUS&lt;/strong&gt;, , affordable pricing, and easy financing options – all in one place." name="description"/>
#   <meta content="Buy used MG Cars in Mumbai, buy used MG cars online in Mumbai, Used MG Cars Online in Mumbai, Second Hand MG Cars in Mumbai, Second Hand MG Cars Online in Mumbai, Buy Second hand MG cars online in Mumbai, Certified Used MG Cars in Mumbai, Pre-owned MG cars online in Mumbai" name="keywords"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <link href="https://www.cars24.com/buy-used-mg-cars-mumbai/" rel="canonical"/>
#   <meta content=" Used MG Cars in Mumbai, Second Hand MG Cars starting from ₹9.90 lakh – CARS24" property="og:title"/>
#   <meta content="Looking to buy a second hand MG car in Mumbai? CARS24 offers a hassle-free experience with a wide range of popular models like  &lt;strong&gt;MG HECTOR&lt;/strong&gt;, &lt;strong&gt;MG HECTOR PLUS&lt;/strong&gt;, , affordable pricing, and easy financing options – all in one place." property="og:description"/>
#   <meta content="https://www.cars24.com/buy-used-mg-cars-mumbai/" property="og:url"/>
#   <meta content="CARS24" property="og:site_name"/>
#   <meta content="https://media.cars24.com/hello-ar/dev/uploads/687754f48d5f5b031269b316/f9bcd127-5175-45c8-9447-c39c62918aba/slot/2-Right-Front-Diagonal.jpg" property="og:image"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content=" Used MG Cars in Mumbai, Second Hand MG Cars starting from ₹9.90 lakh – CARS24" name="twitter:title"/>
#   <meta content="Looking to buy a second hand MG car in Mumbai? CARS24 offers a hassle-free experience with a wide range of popular models like  &lt;strong&gt;MG HECTOR&lt;/strong&gt;, &lt;strong&gt;MG HECTOR PLUS&lt;/strong&gt;, , affordable pricing, and easy financing options – all in one place." name="twitter:description"/>
#   <meta content="https://media.cars24.com/hello-ar/dev/uploads/687754f48d5f5b031269b316/f9bcd127-5175-45c8-9447-c39c62918aba/slot/2-Right-Front-Diagonal.jpg" name="twitter:image"/>
#   <link href="https://assets.cars24.com/static/c2b-website/favicon.ico" rel="shortcut icon"/>
#   <meta name="next-size-adjust"/>
#   <script>
#    (self.__next_s=self.__next_s||[]).push([0,{"children":"\n                    {\n                        (function () {\n                            function handleMessage(event) {\n                                try {\n                                    let message = event.data;\n                                    if (typeof message === \"string\") {\n                                        try {\n                                            message = JSON.parse(message);\n                                        } catch (error) {\n                                            return;\n                                        }\n                                    }\n                                    if (message && message.name === \"APP_LOGIN_EVENT\") {\n                                        window.WEBVIEW_EVENT_NAME = message.name;\n                                        if (message.authToken) {\n                                            window.APP_AUTH_TOKEN = message.authToken;\n                                        }\n                                    }\n                                } catch (error) {\n                                    //\n                                }\n                            }\n                            window.addEventListener(\"message\", handleMessage);\n\n                            window.onunload = function () {\n                                window.removeEventListener(\"message\", handleMessage);\n                            };\n                        })()\n                    }\n                ","id":"app-login-event-handler"}])
#   </script>
#   <script nomodule="" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/chunks/polyfills-42372ed130431b0a.js">
#   </script>
#  </head>
#  <body class="__variable_8c84cb">
#   <!--$-->
#   <!--$-->
#   <!--$?-->
#   <template id="B:0">
#   </template>
#   <div class="container skeleton_header__Fndfe">
#    <div class="skeleton_logoContainer__nEahD">
#     <div class="shimmer skeleton_logo__1AGLL">
#     </div>
#     <div class="shimmer skeleton_city__6SGwm">
#     </div>
#    </div>
#    <div class="skeleton_nav__DYMEr">
#     <div class="shimmer skeleton_menuItem__T_632">
#     </div>
#     <div class="shimmer skeleton_menuItem__T_632">
#     </div>
#     <div class="shimmer skeleton_menuItem__T_632">
#     </div>
#     <div class="shimmer skeleton_menuItem__T_632">
#     </div>
#     <div class="shimmer skeleton_menuItem__T_632">
#     </div>
#    </div>
#    <div class="skeleton_navRightWrapper__KrRsU">
#     <div class="shimmer skeleton_menuIcon__qYjOq">
#     </div>
#     <div class="shimmer skeleton_account__08s_5">
#     </div>
#    </div>
#   </div>
#   <div class="styles_wrapper__NMxXb">
#    <div class="container">
#     <div class="styles_listingContentWrapper__Df4XP">
#      <div class="styles_filterContainer__izG7N">
#       <div class="shimmer styles_filterTab__QsJF0">
#       </div>
#       <div class="shimmer styles_filterHeading___wsjN">
#       </div>
#       <div class="shimmer styles_filterSearchBox___JUCt">
#       </div>
#       <div class="shimmer styles_filterList__OOmks">
#       </div>
#       <div class="shimmer styles_filterHeading___wsjN">
#       </div>
#       <div class="shimmer styles_filterSearchBox___JUCt">
#       </div>
#       <div class="shimmer styles_filterList__OOmks">
#       </div>
#       <div class="shimmer styles_filterHeading___wsjN">
#       </div>
#       <div class="shimmer styles_filterSearchBox___JUCt">
#       </div>
#       <div class="shimmer styles_filterList__OOmks">
#       </div>
#      </div>
#      <div class="styles_carListingContainer__x28_H">
#       <div class="shimmer styles_searchWrap__DWTmT">
#       </div>
#       <div class="shimmer styles_discountBanner__ONf7T">
#       </div>
#       <div class="styles_totalCarsWrap__uA9hS">
#        <div class="shimmer styles_heading__8l7Bn">
#        </div>
#        <div class="shimmer styles_sortBy__FlQoo">
#        </div>
#       </div>
#       <ul class="mb-3">
#        <li class="shimmer styles_textLine__jKU0x">
#        </li>
#        <li class="shimmer styles_textLine__jKU0x">
#        </li>
#        <li class="shimmer styles_more__c4kRU">
#        </li>
#       </ul>
#       <div class="styles_carItem__1pWVa">
#        <div class="styles_skeletonCard__QVBxs">
#         <div class="styles_thumbnail__gzgP5">
#          <div class="styles_thumbnailLoading__i1_q6">
#           <svg fill="none" height="78" width="155" xmlns="http://www.w3.org/2000/svg">
#            <path d="m8.818 35.924-5.251 5.925-1.274 9.856-1.365-3.648-.342-8.661 4.916-7.98 2.55 1.064zM60.266 41.793l-9.145 3.179-2.414 7.342.439 9.97-.043 4.22-3.61-3.04-.423-21.826 6.184-9.755 5.395-1.215 2.523 4.336z" fill="#e8e8e8">
#            </path>
#            <path d="M55.6 40.72q.19-.006.38.004l10.503.107c4.605-.178 8.702 7.663 9.15 17.513.45 9.85-2.919 17.98-7.524 18.158a4 4 0 0 1-.378-.003l-10.504-.107a4 4 0 0 1-.361-.004h-.021c-4.448-.255-8.332-7.932-8.769-17.509-.45-9.85 2.92-17.98 7.525-18.158M8.068 35.525q.159-.007.318.003l8.837.09c3.874-.15 7.321 6.446 7.698 14.733.379 8.287-2.456 15.127-6.33 15.277a3 3 0 0 1-.318-.004l-8.837-.09a4 4 0 0 1-.303-.003h-.018c-3.741-.214-7.01-6.672-7.377-14.73-.378-8.287 2.456-15.126 6.33-15.276M149.523 63.306s-.927 8.82-8.339 9.725c-7.413.906-12.012-.122-12.012-.122s-3.543-1.867-4.622-5.672z" fill="#e8e8e8">
#            <path d="M7.604 33.81c.112 0 .204-.083.205-.188l.03-2.977c.008-5.23 1.805-7.988 3.311-9.382 1.627-1.506 3.274-1.789 3.29-1.79a.2.2 0 0 0 .164-.149c.826-3.675 5.16-10.133 5.203-10.198a.18.18 0 0 0-.063-.261.21.21 0 0 0-.28.059c-.177.264-4.325 6.446-5.227 10.202-.444.098-1.892.507-3.35 1.85-1.57 1.443-3.443 4.292-3.45 9.667l-.03 2.976c-.003.105.087.19.199.191zM45.637 66.428s.045-1.12.046-1.224l.018-1.739v-.011c-.011-.2-.273-4.824-.979-6.03-.014-.276-.097-1.788-.481-5.62q0-.006-.002-.012c-.009-.054-.91-5.562.73-18.487l.72-6.004c.077-.249 1.104-3.494 2.166-4.461a.18.18 0 0 0 .004-.268.213.213 0 0 0-.287-.004c-1.175 1.071-2.232 4.498-2.278 4.644l-.006.03-.722 6.018c-1.62 12.778-.765 18.355-.728 18.584.425 4.24.48 5.625.48 5.638q.003.049.03.09c.664 1.039.937 5.702.947 5.894l-.03 2.958z" fill="#F7F6F6">
#            </path>
#            <path d="M56.645 32.885c8.94 5.456 11.776 27.27 11.776 27.27l-1.618-.04c-2.26-13.56-5.21-18.476-6.386-20.735-1.177-2.258-6.744-9.224-11.754-.176-2.442 4.408-3.008 9.33-2.948 13.216-.62-6.108 1.989-24.992 10.929-19.536" fill="#F7F6F6">
#            </path>
#           </svg>
#          </div>
#         </div>
#         <div class="styles_outer___8Dbj">
#          <div class="shimmer styles_carName__3aZ15">
#          </div>
#          <ul class="styles_uspBadge__XuL5_">
#           <li class="shimmer styles_usp__t9qJI">
#           </li>
#           <li class="shimmer styles_km__3_Do0">
#           </li>
#           <li class="shimmer styles_fuel__L_qcQ">
#           </li>
#           <li class="shimmer styles_owners__9n8kW">
#           </li>
#          </ul>
#          <div class="shimmer styles_pricingDetail__JGGyx">
#          </div>
#          <div class="shimmer styles_assured__ndhKb">
#          </div>
#         </div>
#         <div class="shimmer styles_hubAddress__rJL4w">
#         </div>
#        </div>
#        <div class="styles_skeletonCard__QVBxs">
#         <div class="styles_thumbnail__gzgP5">
#          <div class="styles_thumbnailLoading__i1_q6">
#           <svg fill="none" height="78" width="155" xmlns="http://www.w3.org/2000/svg">
#            <path d="m8.818 35.924-5.251 5.925-1.274 9.856-1.365-3.648-.342-8.661 4.916-7.98 2.55 1.064zM60.266 41.793l-9.145 3.179-2.414 7.342.439 9.97-.043 4.22-3.61-3.04-.423-21.826 6.184-9.755 5.395-1.215 2.523 4.336z" fill="#e8e8e8">
#            </path>
#            <path d="M55.6 40.72q.19-.006.38.004l10.503.107c4.605-.178 8.702 7.663 9.15 17.513.45 9.85-2.919 17.98-7.524 18.158a4 4 0 0 1-.378-.003l-10.504-.107a4 4 0 0 1-.361-.004h-.021c-4.448-.255-8.332-7.932-8.769-17.509-.45-9.85 2.92-17.98 7.525-18.158M8.068 35.525q.159-.007.318.003l8.837.09c3.874-.15 7.321 6.446 7.698 14.733.379 8.287-2.456 15.127-6.33 15.277a3 3 0 0 1-.318-.004l-8.837-.09a4 4 0 0 1-.303-.003h-.018c-3.741-.214-7.01-6.672-7.377-14.73-.378-8.287 2.456-15.126 6.33-15.276M149.523 63.306s-.927 8.82-8.339 9.725c-7.413.906-12.012-.122-12.012-.122s-3.543-1.867-4.622-5.672z" fill="#e8e8e8">
#            <path d="M7.604 33.81c.112 0 .204-.083.205-.188l.03-2.977c.008-5.23 1.805-7.988 3.311-9.382 1.627-1.506 3.274-1.789 3.29-1.79a.2.2 0 0 0 .164-.149c.826-3.675 5.16-10.133 5.203-10.198a.18.18 0 0 0-.063-.261.21.21 0 0 0-.28.059c-.177.264-4.325 6.446-5.227 10.202-.444.098-1.892.507-3.35 1.85-1.57 1.443-3.443 4.292-3.45 9.667l-.03 2.976c-.003.105.087.19.199.191zM45.637 66.428s.045-1.12.046-1.224l.018-1.739v-.011c-.011-.2-.273-4.824-.979-6.03-.014-.276-.097-1.788-.481-5.62q0-.006-.002-.012c-.009-.054-.91-5.562.73-18.487l.72-6.004c.077-.249 1.104-3.494 2.166-4.461a.18.18 0 0 0 .004-.268.213.213 0 0 0-.287-.004c-1.175 1.071-2.232 4.498-2.278 4.644l-.006.03-.722 6.018c-1.62 12.778-.765 18.355-.728 18.584.425 4.24.48 5.625.48 5.638q.003.049.03.09c.664 1.039.937 5.702.947 5.894l-.03 2.958z" fill="#F7F6F6">
#            </path>
#            <path d="M56.645 32.885c8.94 5.456 11.776 27.27 11.776 27.27l-1.618-.04c-2.26-13.56-5.21-18.476-6.386-20.735-1.177-2.258-6.744-9.224-11.754-.176-2.442 4.408-3.008 9.33-2.948 13.216-.62-6.108 1.989-24.992 10.929-19.536" fill="#F7F6F6">
#            </path>
#           </svg>
#          </div>
#         </div>
#         <div class="styles_outer___8Dbj">
#          <div class="shimmer styles_carName__3aZ15">
#          </div>
#          <ul class="styles_uspBadge__XuL5_">
#           <li class="shimmer styles_usp__t9qJI">
#           </li>
#           <li class="shimmer styles_km__3_Do0">
#           </li>
#           <li class="shimmer styles_fuel__L_qcQ">
#           </li>
#           <li class="shimmer styles_owners__9n8kW">
#           </li>
#          </ul>
#          <div class="shimmer styles_pricingDetail__JGGyx">
#          </div>
#          <div class="shimmer styles_assured__ndhKb">
#          </div>
#         </div>
#         <div class="shimmer styles_hubAddress__rJL4w">
#         </div>
#        </div>
#        <div class="styles_skeletonCard__QVBxs">
#         <div class="styles_thumbnail__gzgP5">
#          <div class="styles_thumbnailLoading__i1_q6">
#           <svg fill="none" height="78" width="155" xmlns="http://www.w3.org/2000/svg">
#            <path d="m8.818 35.924-5.251 5.925-1.274 9.856-1.365-3.648-.342-8.661 4.916-7.98 2.55 1.064zM60.266 41.793l-9.145 3.179-2.414 7.342.439 9.97-.043 4.22-3.61-3.04-.423-21.826 6.184-9.755 5.395-1.215 2.523 4.336z" fill="#e8e8e8">
#            </path>
#            <path d="M55.6 40.72q.19-.006.38.004l10.503.107c4.605-.178 8.702 7.663 9.15 17.513.45 9.85-2.919 17.98-7.524 18.158a4 4 0 0 1-.378-.003l-10.504-.107a4 4 0 0 1-.361-.004h-.021c-4.448-.255-8.332-7.932-8.769-17.509-.45-9.85 2.92-17.98 7.525-18.158M8.068 35.525q.159-.007.318.003l8.837.09c3.874-.15 7.321 6.446 7.698 14.733.379 8.287-2.456 15.127-6.33 15.277a3 3 0 0 1-.318-.004l-8.837-.09a4 4 0 0 1-.303-.003h-.018c-3.741-.214-7.01-6.672-7.377-14.73-.378-8.287 2.456-15.126 6.33-15.276M149.523 63.306s-.927 8.82-8.339 9.725c-7.413.906-12.012-.122-12.012-.122s-3.543-1.867-4.622-5.672z" fill="#e8e8e8">
#            <path d="M7.604 33.81c.112 0 .204-.083.205-.188l.03-2.977c.008-5.23 1.805-7.988 3.311-9.382 1.627-1.506 3.274-1.789 3.29-1.79a.2.2 0 0 0 .164-.149c.826-3.675 5.16-10.133 5.203-10.198a.18.18 0 0 0-.063-.261.21.21 0 0 0-.28.059c-.177.264-4.325 6.446-5.227 10.202-.444.098-1.892.507-3.35 1.85-1.57 1.443-3.443 4.292-3.45 9.667l-.03 2.976c-.003.105.087.19.199.191zM45.637 66.428s.045-1.12.046-1.224l.018-1.739v-.011c-.011-.2-.273-4.824-.979-6.03-.014-.276-.097-1.788-.481-5.62q0-.006-.002-.012c-.009-.054-.91-5.562.73-18.487l.72-6.004c.077-.249 1.104-3.494 2.166-4.461a.18.18 0 0 0 .004-.268.213.213 0 0 0-.287-.004c-1.175 1.071-2.232 4.498-2.278 4.644l-.006.03-.722 6.018c-1.62 12.778-.765 18.355-.728 18.584.425 4.24.48 5.625.48 5.638q.003.049.03.09c.664 1.039.937 5.702.947 5.894l-.03 2.958z" fill="#F7F6F6">
#            </path>
#            <path d="M56.645 32.885c8.94 5.456 11.776 27.27 11.776 27.27l-1.618-.04c-2.26-13.56-5.21-18.476-6.386-20.735-1.177-2.258-6.744-9.224-11.754-.176-2.442 4.408-3.008 9.33-2.948 13.216-.62-6.108 1.989-24.992 10.929-19.536" fill="#F7F6F6">
#            </path>
#           </svg>
#          </div>
#         </div>
#         <div class="styles_outer___8Dbj">
#          <div class="shimmer styles_carName__3aZ15">
#          </div>
#          <ul class="styles_uspBadge__XuL5_">
#           <li class="shimmer styles_usp__t9qJI">
#           </li>
#           <li class="shimmer styles_km__3_Do0">
#           </li>
#           <li class="shimmer styles_fuel__L_qcQ">
#           </li>
#           <li class="shimmer styles_owners__9n8kW">
#           </li>
#          </ul>
#          <div class="shimmer styles_pricingDetail__JGGyx">
#          </div>
#          <div class="shimmer styles_assured__ndhKb">
#          </div>
#         </div>
#         <div class="shimmer styles_hubAddress__rJL4w">
#         </div>
#        </div>
#        <div class="styles_skeletonCard__QVBxs">
#         <div class="styles_thumbnail__gzgP5">
#          <div class="styles_thumbnailLoading__i1_q6">
#           <svg fill="none" height="78" width="155" xmlns="http://www.w3.org/2000/svg">
#            <path d="m8.818 35.924-5.251 5.925-1.274 9.856-1.365-3.648-.342-8.661 4.916-7.98 2.55 1.064zM60.266 41.793l-9.145 3.179-2.414 7.342.439 9.97-.043 4.22-3.61-3.04-.423-21.826 6.184-9.755 5.395-1.215 2.523 4.336z" fill="#e8e8e8">
#            </path>
#            <path d="M55.6 40.72q.19-.006.38.004l10.503.107c4.605-.178 8.702 7.663 9.15 17.513.45 9.85-2.919 17.98-7.524 18.158a4 4 0 0 1-.378-.003l-10.504-.107a4 4 0 0 1-.361-.004h-.021c-4.448-.255-8.332-7.932-8.769-17.509-.45-9.85 2.92-17.98 7.525-18.158M8.068 35.525q.159-.007.318.003l8.837.09c3.874-.15 7.321 6.446 7.698 14.733.379 8.287-2.456 15.127-6.33 15.277a3 3 0 0 1-.318-.004l-8.837-.09a4 4 0 0 1-.303-.003h-.018c-3.741-.214-7.01-6.672-7.377-14.73-.378-8.287 2.456-15.126 6.33-15.276M149.523 63.306s-.927 8.82-8.339 9.725c-7.413.906-12.012-.122-12.012-.122s-3.543-1.867-4.622-5.672z" fill="#e8e8e8">
#            <path d="M7.604 33.81c.112 0 .204-.083.205-.188l.03-2.977c.008-5.23 1.805-7.988 3.311-9.382 1.627-1.506 3.274-1.789 3.29-1.79a.2.2 0 0 0 .164-.149c.826-3.675 5.16-10.133 5.203-10.198a.18.18 0 0 0-.063-.261.21.21 0 0 0-.28.059c-.177.264-4.325 6.446-5.227 10.202-.444.098-1.892.507-3.35 1.85-1.57 1.443-3.443 4.292-3.45 9.667l-.03 2.976c-.003.105.087.19.199.191zM45.637 66.428s.045-1.12.046-1.224l.018-1.739v-.011c-.011-.2-.273-4.824-.979-6.03-.014-.276-.097-1.788-.481-5.62q0-.006-.002-.012c-.009-.054-.91-5.562.73-18.487l.72-6.004c.077-.249 1.104-3.494 2.166-4.461a.18.18 0 0 0 .004-.268.213.213 0 0 0-.287-.004c-1.175 1.071-2.232 4.498-2.278 4.644l-.006.03-.722 6.018c-1.62 12.778-.765 18.355-.728 18.584.425 4.24.48 5.625.48 5.638q.003.049.03.09c.664 1.039.937 5.702.947 5.894l-.03 2.958z" fill="#F7F6F6">
#            </path>
#            <path d="M56.645 32.885c8.94 5.456 11.776 27.27 11.776 27.27l-1.618-.04c-2.26-13.56-5.21-18.476-6.386-20.735-1.177-2.258-6.744-9.224-11.754-.176-2.442 4.408-3.008 9.33-2.948 13.216-.62-6.108 1.989-24.992 10.929-19.536" fill="#F7F6F6">
#            </path>
#           </svg>
#          </div>
#         </div>
#         <div class="styles_outer___8Dbj">
#          <div class="shimmer styles_carName__3aZ15">
#          </div>
#          <ul class="styles_uspBadge__XuL5_">
#           <li class="shimmer styles_usp__t9qJI">
#           </li>
#           <li class="shimmer styles_km__3_Do0">
#           </li>
#           <li class="shimmer styles_fuel__L_qcQ">
#           </li>
#           <li class="shimmer styles_owners__9n8kW">
#           </li>
#          </ul>
#          <div class="shimmer styles_pricingDetail__JGGyx">
#          </div>
#          <div class="shimmer styles_assured__ndhKb">
#          </div>
#         </div>
#         <div class="shimmer styles_hubAddress__rJL4w">
#         </div>
#        </div>
#        <div class="styles_skeletonCard__QVBxs">
#         <div class="styles_thumbnail__gzgP5">
#          <div class="styles_thumbnailLoading__i1_q6">
#           <svg fill="none" height="78" width="155" xmlns="http://www.w3.org/2000/svg">
#            <path d="m8.818 35.924-5.251 5.925-1.274 9.856-1.365-3.648-.342-8.661 4.916-7.98 2.55 1.064zM60.266 41.793l-9.145 3.179-2.414 7.342.439 9.97-.043 4.22-3.61-3.04-.423-21.826 6.184-9.755 5.395-1.215 2.523 4.336z" fill="#e8e8e8">
#            </path>
#            <path d="M55.6 40.72q.19-.006.38.004l10.503.107c4.605-.178 8.702 7.663 9.15 17.513.45 9.85-2.919 17.98-7.524 18.158a4 4 0 0 1-.378-.003l-10.504-.107a4 4 0 0 1-.361-.004h-.021c-4.448-.255-8.332-7.932-8.769-17.509-.45-9.85 2.92-17.98 7.525-18.158M8.068 35.525q.159-.007.318.003l8.837.09c3.874-.15 7.321 6.446 7.698 14.733.379 8.287-2.456 15.127-6.33 15.277a3 3 0 0 1-.318-.004l-8.837-.09a4 4 0 0 1-.303-.003h-.018c-3.741-.214-7.01-6.672-7.377-14.73-.378-8.287 2.456-15.126 6.33-15.276M149.523 63.306s-.927 8.82-8.339 9.725c-7.413.906-12.012-.122-12.012-.122s-3.543-1.867-4.622-5.672z" fill="#e8e8e8">
#           Used Cars in Chandrapur
#          </a>
#          <a href="/buy-used-cars-shahjahanpur/">
#           Used Cars in Shahjahanpur
#          </a>
#          <a href="/buy-used-cars-hassan/">
#           Used Cars in Hassan
#          </a>
#          <a href="/buy-used-cars-dindigul/">
#           Used Cars in Dindigul
#          </a>
#          <a href="/buy-used-cars-namakkal/">
#           Used Cars in Namakkal
#          </a>
#          <a href="/buy-used-cars-malappuram/">
#           Used Cars in Malappuram
#          </a>
#          <a href="/buy-used-cars-tirur/">
#           Used Cars in Tirur
#          </a>
#          <a href="/buy-used-cars-muvattupuzha/">
#           Used Cars in Muvattupuzha
#          </a>
#          <a href="/buy-used-cars-sambalpur/">
#           Used Cars in Sambalpur
#          </a>
#         </div>
#         <div class="styles_links__gMQAw">
#          <p class="sc-dsLQwm hpYnxU">
#           Owners
#          </p>
#          <a href="/buy-used-first-owner-cars-mumbai/">
#           Used First Owner Cars in Mumbai
#          </a>
#         </div>
#         <div class="styles_links__gMQAw">
#          <p class="sc-dsLQwm hpYnxU">
#           Explore By
#          </p>
#          <a href="/buy-used-sunroof-cars-mumbai/">
#           Used Cars with Sunroof in Mumbai
#          </a>
#         </div>
#         <div class="styles_links__gMQAw">
#          <p class="sc-dsLQwm hpYnxU">
#           CARS24 Hubs in Mumbai
#          </p>
#          <a href="/buy-used-cars-at-cars24-hub-mulund-west-mumbai/">
#           CARS24 Hub, Mulund West
#          </a>
#          <a href="/buy-used-cars-at-cars24-hub-goregaon-mumbai/">
#           CARS24 Hub, Goregaon
#          </a>
#          <a href="/buy-used-cars-at-cars24-hub-seawood-mumbai/">
#           CARS24 Hub, Seawood
#          </a>
#          <a href="/buy-used-cars-at-cars24-hub-kandivali-mumbai-mumbai/">
#           CARS24 Hub, Kandivali, Mumbai
#          </a>
#          <a href="/buy-used-cars-at-cars24-hub-regency-anantam-dombivli-east-mumbai-mumbai/">
#           CARS24 Hub, Regency Anantam, Dombivli East, Mumbai
#          </a>
#          <a href="/buy-used-cars-at-cars24-hub-korum-mall-thane-west-mumbai-mumbai/">
#           CARS24 Hub, Korum Mall, Thane West , Mumbai
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <footer class="sc-jLflnl jcNHRy" style="background:linear-gradient(270deg, rgba(251, 255, 246, 0.20) 0.45%, rgba(255, 255, 255, 0.00) 194.45%), linear-gradient(1deg, rgba(171, 254, 214, 0.20) 15.19%, rgba(228, 254, 186, 0.20) 76.1%, rgba(255, 255, 255, 0.20) 105.61%)">
#     <div>
#      <div class="sc-jNXfOT hfCnxw">
#       <img alt="Cars24" height="24" loading="lazy" src="https://static-cdn.cars24.com/qa/cms/2025/01/27/686dd5d2-3819-4318-b957-281609917fadLogo.png" width="54"/>
#       <span>
#        |
#       </span>
#       <h3 class="sc-fvMZNI iOuLzz">
#        Better drives, better lives
#       </h3>
#      </div>
#      <div class="sc-gkavYR jcWOij">
#       <div class="sc-exkVDC fwgMTp">
#        <div>
#         <div class="sc-iMDhdf kBxvEF">
#          <p class="sc-loAbOW jGQtht">
#           Company
#          </p>
#          <ul class="sc-bPZXsP cTbVOy">
#           <li>
#            <a href="https://www.cars24.com/about-us/">
#             About Us
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/careers/">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/press-kit/">
#             Press kit
#            </a>
#           </li>
#           <li>
#            <a href="https://autonauts.cars24.com/">
#             Blog
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/article/">
#             Article
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/news/">
#             News
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/privacy-policy/">
#             Privacy Policy
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/sustainability/">
#             Sustainability
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/testimonials/">
#             Testimonials
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div>
#         <div class="sc-iMDhdf kBxvEF">
#          <p class="sc-loAbOW jGQtht">
#           Discover
#          </p>
#          <ul class="sc-bPZXsP cTbVOy">
#           <li>
#            <a href="https://www.cars24.com/buy-used-cars/">
#             Buy used car
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/sell-used-cars/">
#             Sell used car
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/used-car-valuation/">
#             Used car valuation
#            </a>
#           </li>
#           <li>
#            <a href="https://insure24.com/">
#             Motor insurance
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/traffic-challan/">
#             Check &amp; pay challan
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/rto-vehicle-registration-details/">
#             Check vehicle details
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/new-cars/">
#             Explore new cars
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/scrap-cars/">
#             Scrap your car
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div>
#         <div class="sc-iMDhdf kBxvEF">
#          <p class="sc-loAbOW jGQtht">
#           Help &amp; support
#          </p>
#          <ul class="sc-bPZXsP cTbVOy">
#           <li>
#            <a href="https://www.cars24.com/faq/">
#             FAQs
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/security/">
#             Security
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/contact/">
#             Contact us
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/become-our-partner/">
#             Become a partner
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/rc-transfer/">
#             RC transfer status
#            </a>
#           </li>
#           <li>
#            <a href="https://www.cars24.com/terms-and-conditions/">
#             Terms &amp; conditions
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="sc-krqSwS ikdKBK">
#        <p class="sc-loAbOW jGQtht">
#         Social Links
#        </p>
#        <ul class="sc-dvVHDY brMwS">
#         <li>
#          <a href="https://www.facebook.com/cars24india/">
#           <img alt="Facebook" loading="lazy" src="https://cdn.cars24.com/qa/cms/2025/01/28/20bc036d-1141-4ebd-8d20-7b1375870066facebook.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="https://x.com/cars24india/">
#           <img alt="x" loading="lazy" src="https://cdn.cars24.com/qa/cms/2025/01/28/710ea14d-190f-4955-bb11-0743e5a3627ex.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.instagram.com/cars24india/">
#           <img alt="Instagram" loading="lazy" src="https://cdn.cars24.com/qa/cms/2025/01/28/744c742a-864f-4616-9a25-c664d0dbb652instragram.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.youtube.com/channel/UCV-CPspQhwTsaiftR4JvT0w">
#           <img alt="Youtube" loading="lazy" src="https://cdn.cars24.com/qa/cms/2025/01/28/456bd9b6-6fca-4659-8c6c-427c6f571317youtube.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.linkedin.com/company/cars24/">
#           <img alt="LinkedIn" loading="lazy" src="https://cdn.cars24.com/qa/cms/2025/01/28/1cf9514f-9a2b-44df-8407-9eb9c5984812linkin.png"/>
#          </a>
#         </li>
#        </ul>
#        <div class="sc-SQOaL rdHfY">
#         <a href="https://apps.apple.com/in/app/cars24-sell-buy-used-cars/id1364492085">
#          <img alt="App Store" height="47px" loading="lazy" src="https://cdn.cars24.com/qa/cms/2025/01/28/af06855c-ff0e-4af6-8430-26358b691fe4appstore.png" width="160px"/>
#         </a>
#         <a href="https://play.google.com/store/apps/details?id=com.cars24.seller&amp;referrer=utm_source%3Dapp-download%26utm_medium%3Dweb-footer">
#          <img alt="Play Store" height="47px" loading="lazy" src="https://cdn.cars24.com/qa/cms/2025/01/28/792eefd8-bb3c-4401-a763-f21806591741playstore.png" width="160px"/>
#         </a>
#        </div>
#        <p class="sc-loAbOW jGQtht">
#         We are global
#        </p>
#        <ul class="sc-fmRmGN kNXdOF">
#         <li>
#          <a href="https://www.cars24.com.au/">
#           <img alt="Australia" loading="lazy" src="https://cdn.cars24.com/qa/cms/2025/01/28/6b5b5a14-3e69-4fbb-9827-86ba7eb00521australia.png"/>
#           <p class="sc-bTwLay hwVbEN">
#            Australia
#           </p>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.cars24.ae/">
#           <img alt="UAE" loading="lazy" src="https://cdn.cars24.com/qa/cms/2025/01/28/115ef785-4593-4773-90a1-60d8e0f1c6c8uae.png"/>
#           <p class="sc-bTwLay hwVbEN">
#            UAE
#           </p>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <p class="sc-eteQWc dgrzLN">
#      © 2025 CARS24, All rights reserved
#     </p>
#    </footer>
#    <!--$!-->
#    <template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING">
#    </template>
#    <!--/$-->
#    <div class="styles_chatRevampContainer__x_JuF">
#     <div class="styles_chatContainer__wDr0W">
#      <img alt="need help" data-nimg="1" decoding="async" height="24" loading="lazy" src="https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/media/help-icon.48d6fb88.svg" style="color:transparent" width="24"/>
#      <span class="styles_tooltip__fZ2TU">
#       Need help?
#      </span>
#     </div>
#    </div>
#    <!--$!-->
#    <template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING">
#    </template>
#    <!--/$-->
#    <!--$!-->
#    <template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING">
#    </template>
#    <!--/$-->
#   </div>
#   <script>
#    $RS=function(a,b){a=document.getElementById(a);b=document.getElementById(b);for(a.parentNode.removeChild(a);a.firstChild;)b.parentNode.insertBefore(a.firstChild,b);b.parentNode.removeChild(b)};$RS("S:1","P:1")
#   </script>
#   <script>
#    $RC=function(b,c,e){c=document.getElementById(c);c.parentNode.removeChild(c);var a=document.getElementById(b);if(a){b=a.previousSibling;if(e)b.data="$!",a.setAttribute("data-dgst",e);else{e=b.parentNode;a=b.nextSibling;var f=0;do{if(a&&8===a.nodeType){var d=a.data;if("/$"===d)if(0===f)break;else f--;else"$"!==d&&"$?"!==d&&"$!"!==d||f++}d=a.nextSibling;e.removeChild(a);a=d}while(a);for(;c.firstChild;)e.insertBefore(c.firstChild,a);b.data="$"}b._reactRetry&&b._reactRetry()}};$RM=new Map;
# $RR=function(r,t,w){for(var u=$RC,n=$RM,p=new Map,q=document,g,b,h=q.querySelectorAll("link[data-precedence],style[data-precedence]"),v=[],k=0;b=h[k++];)"not all"===b.getAttribute("media")?v.push(b):("LINK"===b.tagName&&n.set(b.getAttribute("href"),b),p.set(b.dataset.precedence,g=b));b=0;h=[];var l,a;for(k=!0;;){if(k){var f=w[b++];if(!f){k=!1;b=0;continue}var c=!1,m=0;var d=f[m++];if(a=n.get(d)){var e=a._p;c=!0}else{a=q.createElement("link");a.href=d;a.rel="stylesheet";for(a.dataset.precedence=
# l=f[m++];e=f[m++];)a.setAttribute(e,f[m++]);e=a._p=new Promise(function(x,y){a.onload=x;a.onerror=y});n.set(d,a)}d=a.getAttribute("media");!e||"l"===e.s||d&&!matchMedia(d).matches||h.push(e);if(c)continue}else{a=v[b++];if(!a)break;l=a.getAttribute("data-precedence");a.removeAttribute("media")}c=p.get(l)||g;c===g&&(g=a);p.set(l,a);c?c.parentNode.insertBefore(a,c.nextSibling):(c=q.head,c.insertBefore(a,c.firstChild))}Promise.all(h).then(u.bind(null,r,t,""),u.bind(null,r,t,"Resource failed to load"))};$RR("B:0","S:0",[["https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/04e60d001684c433.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/e6f355622f4091f5.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/47cde6cb9ef97f48.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/f9a4908e529bdafe.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/2bab40dd3e0b6b56.css","dynamic","as","style"],["https://assets.cars24.com/production/catalog-web-in/250717161258/_next/static/css/86182671d5dcd1cf.css","dynamic","as","style"]])
#   </script>
#  </body>
# </html>

# %%
car_cards = soup.find_all('a', class_="styles_carCardWrapper__sXLIp")

# %%
cars_data=[]
for card in car_cards:
    try:
        title = card.find('span', class_="sc-braxZu kjFjan").text.strip()
        variant = card.find('span', class_="sc-braxZu fccwQo").text.strip()

        details = card.find_all('p', class_="sc-braxZu kvfdZL")
        km_driven = details[0].text.strip()
        fuel_type = details[1].text.strip()
        transmission = details[2].text.strip()
        owners = details[3].text.strip()

        price = card.find('p', class_="sc-braxZu cyPhJl").text.strip()

        location = card.find('p', class_="sc-braxZu lmmumg").text.strip()

        year_match = re.search(r'\b(19|20)\d{2}\b', title)
        manufacture_year = year_match.group(0) if year_match else None

        cars_data.append({
            "Manufacture Year": manufacture_year,
            "Title": title,
            "Variant": variant,
            "Kilometers Driven": km_driven,
            "Fuel Type": fuel_type,
            "Transmission": transmission,
            "Owners": owners,
            "Price": price,
            "Location": location

        })
    except Exception as e:
          continue

df = pd.DataFrame(cars_data)
from IPython.display import display
display(df)

df.to_csv("/content/mg_cars_mumbai.csv", index=False)
# Out:
#   Manufacture Year                Title                           Variant  \
# 0             2023  2023 MG HECTOR PLUS      SHARP PRO 1.5 TURBO MT 7 STR
# 1             2021       2021 MG HECTOR              SHARP 1.5 PETROL CVT
# 2             2019       2019 MG HECTOR              SHARP 1.5 DCT PETROL
# 3             2023  2023 MG HECTOR PLUS    SHARP PLUS 2.0 D TURBO MT 6STR
# 4             2020  2020 MG HECTOR PLUS  SHARP 1.5 PETROL TURBO DCT 6-STR
# 5             2021       2021 MG HECTOR                  SUPER 2.0 DIESEL
# 6             2022       2022 MG HECTOR                  SHARP 2.0 DIESEL
#
#   Kilometers Driven Fuel Type Transmission     Owners        Price  \
# 0         12.52k km    Petrol       Manual  1st owner  ₹20.52 lakh
# 1         48.87k km    Petrol         Auto  2nd owner  ₹11.90 lakh
# 2         74.19k km    Petrol         Auto  1st owner   ₹9.90 lakh
# 3         29.18k km    Diesel       Manual  1st owner  ₹16.20 lakh
# 4         32.71k km    Petrol         Auto  2nd owner  ₹11.20 lakh
# 5         64.54k km    Diesel       Manual  1st owner  ₹12.81 lakh
# 6         22.22k km    Diesel       Manual  1st owner  ₹14.40 lakh
#
#                          Location
# 0               Kandivali, Mumbai
# 1               Kandivali, Mumbai
# 2          Korum Mall, Thane West
# 3  Regency Anantam, Dombivli East
# 4             Mulund West, Mumbai
# 5          Korum Mall, Thane West
# 6                Goregaon, Mumbai

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv("C:/Users/adi33/OneDrive/Desktop/INTERNSHIP/mg_cars_mumbai.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-45-4277130235.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("C:/Users/adi33/OneDrive/Desktop/INTERNSHIP/mg_cars_mumbai.csv")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/adi33/OneDrive/Desktop/INTERNSHIP/mg_cars_mumbai.csv'

# %%
print("First Few rows:")
from IPython.display import display
display(df)
# Out:
# First Few rows:
#   Manufacture Year                Title                           Variant  \
# 0             2023  2023 MG HECTOR PLUS      SHARP PRO 1.5 TURBO MT 7 STR
# 1             2021       2021 MG HECTOR              SHARP 1.5 PETROL CVT
# 2             2019       2019 MG HECTOR              SHARP 1.5 DCT PETROL
# 3             2023  2023 MG HECTOR PLUS    SHARP PLUS 2.0 D TURBO MT 6STR
# 4             2020  2020 MG HECTOR PLUS  SHARP 1.5 PETROL TURBO DCT 6-STR
# 5             2021       2021 MG HECTOR                  SUPER 2.0 DIESEL
# 6             2022       2022 MG HECTOR                  SHARP 2.0 DIESEL
#
#   Kilometers Driven Fuel Type Transmission     Owners        Price  \
# 0         12.52k km    Petrol       Manual  1st owner  ₹20.52 lakh
# 1         48.87k km    Petrol         Auto  2nd owner  ₹11.90 lakh
# 2         74.19k km    Petrol         Auto  1st owner   ₹9.90 lakh
# 3         29.18k km    Diesel       Manual  1st owner  ₹16.20 lakh
# 4         32.71k km    Petrol         Auto  2nd owner  ₹11.20 lakh
# 5         64.54k km    Diesel       Manual  1st owner  ₹12.81 lakh
# 6         22.22k km    Diesel       Manual  1st owner  ₹14.40 lakh
#
#                          Location
# 0               Kandivali, Mumbai
# 1               Kandivali, Mumbai
# 2          Korum Mall, Thane West
# 3  Regency Anantam, Dombivli East
# 4             Mulund West, Mumbai
# 5          Korum Mall, Thane West
# 6                Goregaon, Mumbai

# %%
print("\n Dataset Info:")
df.info()
# Out:
#  Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Manufacture Year   7 non-null      object
#  1   Title              7 non-null      object
#  2   Variant            7 non-null      object
#  3   Kilometers Driven  7 non-null      object
#  4   Fuel Type          7 non-null      object
#  5   Transmission       7 non-null      object
#  6   Owners             7 non-null      object
#  7   Price              7 non-null      object
#  8   Location           7 non-null      object
# dtypes: object(9)
# memory usage: 636.0+ bytes

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Manufacture Year     0
# Title                0
# Variant              0
# Kilometers Driven    0
# Fuel Type            0
# Transmission         0
# Owners               0
# Price                0
# Location             0
# dtype: int64

# %%
print("\nStatistical Summary:")
from IPython.display import display
display(df.describe(include='all'))
# Out:
# Statistical Summary:
#        Manufacture Year                Title                       Variant  \
# count                 7                    7                             7
# unique                5                    5                             7
# top                2023  2023 MG HECTOR PLUS  SHARP PRO 1.5 TURBO MT 7 STR
# freq                  2                    2                             1
#
#        Kilometers Driven Fuel Type Transmission     Owners        Price  \
# count                  7         7            7          7            7
# unique                 7         2            2          2            7
# top            12.52k km    Petrol       Manual  1st owner  ₹20.52 lakh
# freq                   1         4            4          5            1
#
#                  Location
# count                   7
# unique                  5
# top     Kandivali, Mumbai
# freq                    2

# %% [markdown]
# **Data Cleaning**

# %%
# Converting 'Kilometers Driven' like "29.18k km" to integers
df['Kilometers Driven'] = df['Kilometers Driven'].astype(str).str.lower().str.replace('km', '', regex=False)
df['Kilometers Driven'] = df['Kilometers Driven'].str.replace('k', '000', regex=False)
df['Kilometers Driven'] = df['Kilometers Driven'].str.replace('.', '', regex=False)
df['Kilometers Driven'] = df['Kilometers Driven'].str.replace(',', '', regex=False).astype(int)

# %%
# Converting 'Price' like "₹16.90 lakh" to integers
df['Price'] = df['Price'].str.replace('₹', '', regex=False)
df['Price'] = df['Price'].str.replace(' lakh', '', regex=False)
df['Price'] = df['Price'].str.replace(',', '', regex=False).astype(float) * 1_00_000
df['Price'] = df['Price'].astype(int)

# %%
# Extracting numeric owner count from "1st owner"
df['Owners'] = df['Owners'].astype(str).str.extract(r'(\d)').astype(int)

# %%
# Ensuring 'Manufacture Year' is numeric
df['Manufacture Year'] = pd.to_numeric(df['Manufacture Year'], errors='coerce')

# %%
# Show cleaned data
print("\n Cleaned Data Sample:")
from IPython.display import display
display(df)
# Out:
#  Cleaned Data Sample:
#    Manufacture Year                Title                           Variant  \
# 0              2023  2023 MG HECTOR PLUS      SHARP PRO 1.5 TURBO MT 7 STR
# 1              2021       2021 MG HECTOR              SHARP 1.5 PETROL CVT
# 2              2019       2019 MG HECTOR              SHARP 1.5 DCT PETROL
# 3              2023  2023 MG HECTOR PLUS    SHARP PLUS 2.0 D TURBO MT 6STR
# 4              2020  2020 MG HECTOR PLUS  SHARP 1.5 PETROL TURBO DCT 6-STR
# 5              2021       2021 MG HECTOR                  SUPER 2.0 DIESEL
# 6              2022       2022 MG HECTOR                  SHARP 2.0 DIESEL
#
#    Kilometers Driven Fuel Type Transmission  Owners    Price  \
# 0            1252000    Petrol       Manual       1  2052000
# 1            4887000    Petrol         Auto       2  1190000
# 2            7419000    Petrol         Auto       1   990000
# 3            2918000    Diesel       Manual       1  1620000
# 4            3271000    Petrol         Auto       2  1120000
# 5            6454000    Diesel       Manual       1  1281000
# 6            2222000    Diesel       Manual       1  1440000
#
#                          Location
# 0               Kandivali, Mumbai
# 1               Kandivali, Mumbai
# 2          Korum Mall, Thane West
# 3  Regency Anantam, Dombivli East
# 4             Mulund West, Mumbai
# 5          Korum Mall, Thane West
# 6                Goregaon, Mumbai

# %% [markdown]
# EXPLORATORY DATA ANALYSIS (EDA)
# ##

# %% [markdown]
# ## Distribution Plots

# %%
# Price distribution
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df['Price'], bins=10, kde=True)
plt.title("Price Distribution (in ₹)")
plt.xlabel("Price (INR)")
plt.ylabel("Number of Cars")
plt.grid(True)
plt.show()

# %%
# Year distribution
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Manufacture Year')
plt.title("Manufacturing Year Distribution")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Kilometers Driven vs Price
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Kilometers Driven', y='Price', hue='Fuel Type')
plt.title("Price vs Kilometers Driven")
plt.grid(True)
plt.show()

# %% [markdown]
# Categorical Analysis

# %%
# Fuel type distribution
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Fuel Type')
plt.title("Fuel Type Distribution")
plt.grid(True)
plt.show()

# %%
# Transmission distribution
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Transmission')
plt.title("Transmission Type Distribution")
plt.grid(True)
plt.show()

# %%
# Owners vs Price
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x='Owners', y='Price', data=df)
plt.title("Price vs Owners")
plt.show()

# %% [markdown]
#     Correlation Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

correlation = df[['Kilometers Driven', 'Price', 'Manufacture Year', 'Owners']].corr()

sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Location wise Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_locations = df['Location'].value_counts().head(10)

sns.barplot(x=top_locations.values, y=top_locations.index)
plt.title("Top 10 Locations with Most Listings")
plt.xlabel("Number of Cars")
plt.ylabel("Location")
plt.show()
